# %%
#Data Ingestion and Data Cleaning
#import mortality rate of under 5, for all country
import pandas as pd

url = "https://ourworldindata.org/grapher/under-5-mortality-rate-sdgs.csv?v=1&csvType=full&useColumnShortNames=true"
mortality_under_5 = pd.read_csv(url, storage_options={'User-Agent': 'Our World In Data data fetch/1.0'})

print(mortality_under_5.shape)
mortality_under_5.head()
# Out:
# (13980, 4)
#         entity code  year  \
# 0  Afghanistan  AFG  1957
# 1  Afghanistan  AFG  1958
# 2  Afghanistan  AFG  1959
# 3  Afghanistan  AFG  1960
# 4  Afghanistan  AFG  1961
#
#    observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births
# 0                                          36.819660
# 1                                          36.206852
# 2                                          35.644524
# 3                                          35.055080
# 4                                          34.519325

# %%
#Improving the under_5_mortality rate to per 1000 from the per hundred the data came with, though it doesnt
#have effect on the result because, i will just multiply 10 to each values from the per 100 to make it represt
#perr 1000 which is the general accepted when dealing with population statistics
mortality_under_5["per_1000"] = mortality_under_5["observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births"] * 10
mortality_under_5.head()
# Out:
#         entity code  year  \
# 0  Afghanistan  AFG  1957
# 1  Afghanistan  AFG  1958
# 2  Afghanistan  AFG  1959
# 3  Afghanistan  AFG  1960
# 4  Afghanistan  AFG  1961
#
#    observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births  \
# 0                                          36.819660
# 1                                          36.206852
# 2                                          35.644524
# 3                                          35.055080
# 4                                          34.519325
#
#     per_1000
# 0  368.19660
# 1  362.06852
# 2  356.44524
# 3  350.55080
# 4  345.19325

# %%
print(mortality_under_5["code"].unique())
# Out:
# ['AFG' 'OWID_AFR' 'ALB' 'DZA' 'AND' 'AGO' 'AIA' 'ATG' 'ARG' 'ARM'
#  'OWID_ASI' 'AUS' 'AUT' 'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ'
#  'BEN' 'BTN' 'BOL' 'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'KHM'
#  'CMR' 'CAN' 'CPV' 'CAF' 'TCD' 'CHL' 'CHN' 'COL' 'COM' 'COG' 'COK' 'CRI'
#  'CIV' 'HRV' 'CUB' 'CYP' 'CZE' 'COD' 'DNK' 'DJI' 'DMA' 'DOM' 'TLS' 'ECU'
#  'EGY' 'SLV' 'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'OWID_EUR' 'OWID_EU27' 'FJI'
#  'FIN' 'FRA' 'GAB' 'GMB' 'GEO' 'DEU' 'GHA' 'GRC' 'GRD' 'GTM' 'GIN' 'GNB'
#  'GUY' 'HTI' 'OWID_HIC' 'HND' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL'
#  'ISR' 'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'OWID_KOS' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LTU' 'OWID_LIC' 'OWID_LMC' 'LUX'
#  'MDG' 'MWI' 'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA'
#  'MCO' 'MNG' 'MNE' 'MSR' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NZL'
#  'NIC' 'NER' 'NGA' 'NIU' 'OWID_NAM' 'PRK' 'MKD' 'NOR' 'OWID_OCE' 'OMN'
#  'PAK' 'PLW' 'PSE' 'PAN' 'PNG' 'PRY' 'PER' 'PHL' 'POL' 'PRT' 'QAT' 'ROU'
#  'RUS' 'RWA' 'KNA' 'LCA' 'VCT' 'WSM' 'SMR' 'STP' 'SAU' 'SEN' 'SRB' 'SYC'
#  'SLE' 'SGP' 'SVK' 'SVN' 'SLB' 'SOM' 'ZAF' 'OWID_SAM' 'KOR' 'SSD' 'ESP'
#  'LKA' 'SDN' 'SUR' 'SWE' 'CHE' 'SYR' 'TJK' 'TZA' 'THA' 'TGO' 'TON' 'TTO'
#  'TUN' 'TUR' 'TKM' 'TCA' 'TUV' 'UGA' 'UKR' 'ARE' 'GBR' 'USA' 'OWID_UMC'
#  'URY' 'UZB' 'VUT' 'VEN' 'VNM' 'OWID_WRL' 'YEM' 'ZMB' 'ZWE']

# %%
# pip install pycountry pandas
# !pip install pycountry
import pycountry
import pandas as pd

countries = []
for c in pycountry.countries:
    countries.append({
        'country_name': c.name,
        'iso_alpha3': c.alpha_3
    })

iso_data = pd.DataFrame(countries).sort_values('country_name').reset_index(drop=True)
print(iso_data.head())
# Out:
# Collecting pycountry
#   Downloading pycountry-26.2.16-py3-none-any.whl.metadata (12 kB)
# Downloading pycountry-26.2.16-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 49.0 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-26.2.16
#      country_name iso_alpha3
# 0     Afghanistan        AFG
# 1         Albania        ALB
# 2         Algeria        DZA
# 3  American Samoa        ASM
# 4         Andorra        AND

# %%
#Rename the column that contains the code for each country of iso data, so i can merge it with under_5 mortality data
iso_data = iso_data.rename(columns={'iso_alpha3': 'code', "country_name":"entity"})
iso_data.head()
# Out:
#            entity code
# 0     Afghanistan  AFG
# 1         Albania  ALB
# 2         Algeria  DZA
# 3  American Samoa  ASM
# 4         Andorra  AND

# %%
#Merge under_5_mertality data on the left with iso_data so as to filter the data to all country,
#because the under_5_mortality data as some world back indicator in between which does not belong to any country
mortality_under_5_new = pd.merge(mortality_under_5, iso_data, on=['code', "entity"], how='left')
mortality_under_5_new.head()
# Out:
#         entity code  year  \
# 0  Afghanistan  AFG  1957
# 1  Afghanistan  AFG  1958
# 2  Afghanistan  AFG  1959
# 3  Afghanistan  AFG  1960
# 4  Afghanistan  AFG  1961
#
#    observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births  \
# 0                                          36.819660
# 1                                          36.206852
# 2                                          35.644524
# 3                                          35.055080
# 4                                          34.519325
#
#     per_1000
# 0  368.19660
# 1  362.06852
# 2  356.44524
# 3  350.55080
# 4  345.19325

# %%
#Validating my new data
print(mortality_under_5.shape)
print(mortality_under_5_new.shape)
# Out:
# (13980, 5)
# (13980, 5)

# %%
#Then merge isn't the proper method, i will try filter method
mortality_under_5_new_2 = mortality_under_5[mortality_under_5["code"].isin(iso_data["code"])]
print(mortality_under_5_new_2.shape)
mortality_under_5_new_2.head()
# Out:
# (13255, 5)
#         entity code  year  \
# 0  Afghanistan  AFG  1957
# 1  Afghanistan  AFG  1958
# 2  Afghanistan  AFG  1959
# 3  Afghanistan  AFG  1960
# 4  Afghanistan  AFG  1961
#
#    observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births  \
# 0                                          36.819660
# 1                                          36.206852
# 2                                          35.644524
# 3                                          35.055080
# 4                                          34.519325
#
#     per_1000
# 0  368.19660
# 1  362.06852
# 2  356.44524
# 3  350.55080
# 4  345.19325

# %%
#validating if we have all countries in the list
print(mortality_under_5_new_2["code"].unique())
unique_coutries = mortality_under_5_new_2["code"].unique()
print(len(unique_coutries))
# Out:
# ['AFG' 'ALB' 'DZA' 'AND' 'AGO' 'AIA' 'ATG' 'ARG' 'ARM' 'AUS' 'AUT' 'AZE'
#  'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BTN' 'BOL' 'BIH' 'BWA'
#  'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'KHM' 'CMR' 'CAN' 'CPV' 'CAF' 'TCD'
#  'CHL' 'CHN' 'COL' 'COM' 'COG' 'COK' 'CRI' 'CIV' 'HRV' 'CUB' 'CYP' 'CZE'
#  'COD' 'DNK' 'DJI' 'DMA' 'DOM' 'TLS' 'ECU' 'EGY' 'SLV' 'GNQ' 'ERI' 'EST'
#  'SWZ' 'ETH' 'FJI' 'FIN' 'FRA' 'GAB' 'GMB' 'GEO' 'DEU' 'GHA' 'GRC' 'GRD'
#  'GTM' 'GIN' 'GNB' 'GUY' 'HTI' 'HND' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ'
#  'IRL' 'ISR' 'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'KWT' 'KGZ' 'LAO'
#  'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LTU' 'LUX' 'MDG' 'MWI' 'MYS' 'MDV' 'MLI'
#  'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG' 'MNE' 'MSR' 'MAR'
#  'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NZL' 'NIC' 'NER' 'NGA' 'NIU' 'PRK'
#  'MKD' 'NOR' 'OMN' 'PAK' 'PLW' 'PSE' 'PAN' 'PNG' 'PRY' 'PER' 'PHL' 'POL'
#  'PRT' 'QAT' 'ROU' 'RUS' 'RWA' 'KNA' 'LCA' 'VCT' 'WSM' 'SMR' 'STP' 'SAU'
#  'SEN' 'SRB' 'SYC' 'SLE' 'SGP' 'SVK' 'SVN' 'SLB' 'SOM' 'ZAF' 'KOR' 'SSD'
#  'ESP' 'LKA' 'SDN' 'SUR' 'SWE' 'CHE' 'SYR' 'TJK' 'TZA' 'THA' 'TGO' 'TON'
#  'TTO' 'TUN' 'TUR' 'TKM' 'TCA' 'TUV' 'UGA' 'UKR' 'ARE' 'GBR' 'USA' 'URY'
#  'UZB' 'VUT' 'VEN' 'VNM' 'YEM' 'ZMB' 'ZWE']
# 199

# %%
#Importing data for income category for each country
import requests
import pandas as pd

# Pull country metadata including income classification
url = "https://api.worldbank.org/v2/country?format=json&per_page=300"
response = requests.get(url)
data = response.json()[1]
# index 0 is pagination info, index 1 is the actual data

# Flatten the nested structure
income_level = pd.DataFrame([
    {
        "Code": c["id"],
        "country_name": c["name"],
        "income_group": c["incomeLevel"]["value"],
        "region": c["region"]["value"]
    }
    for c in data
])

# Drop non-country aggregates (World Bank includes regional groupings here too)
income_level = income_level[income_level["income_group"] != "Aggregates"]

print(income_level["income_group"].unique())
income_level.head()
# Out:
# ['High income' 'Low income' 'Lower middle income' 'Upper middle income']
#   Code country_name         income_group  \
# 0  ABW        Aruba          High income
# 2  AFG  Afghanistan           Low income
# 5  AGO       Angola  Lower middle income
# 6  ALB      Albania  Upper middle income
# 7  AND      Andorra          High income
#
#                                               region
# 0                         Latin America & Caribbean
# 2  Middle East, North Africa, Afghanistan & Pakistan
# 5                                Sub-Saharan Africa
# 6                              Europe & Central Asia
# 7                              Europe & Central Asia

# %%
#Now i have my income level data, so i will like extract two columns from it to the mortarlit data
mortality_under_5_new_2["income_level"] = mortality_under_5_new_2[mortality_under_5_new_2['code'].isin(income_level['Code'])]['code'].map(income_level.set_index('Code')['income_group'])
mortality_under_5_new_2
# Out:
# /tmp/ipykernel_2533/2526433006.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mortality_under_5_new_2["income_level"] = mortality_under_5_new_2[mortality_under_5_new_2['code'].isin(income_level['Code'])]['code'].map(income_level.set_index('Code')['income_group'])
#             entity code  year  \
# 0      Afghanistan  AFG  1957
# 1      Afghanistan  AFG  1958
# 2      Afghanistan  AFG  1959
# 3      Afghanistan  AFG  1960
# 4      Afghanistan  AFG  1961
# ...            ...  ...   ...
# 13975     Zimbabwe  ZWE  2020
# 13976     Zimbabwe  ZWE  2021
# 13977     Zimbabwe  ZWE  2022
# 13978     Zimbabwe  ZWE  2023
# 13979     Zimbabwe  ZWE  2024
#
#        observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births  \
# 0                                              36.819660
# 1                                              36.206852
# 2                                              35.644524
# 3                                              35.055080
# 4                                              34.519325
# ...                                                  ...
# 13975                                           6.165443
# 13976                                           6.237477
# 13977                                           6.403628
# 13978                                           6.419753
# 13979                                           6.466091
#
#          per_1000         income_level
# 0      368.196600           Low income
# 1      362.068520           Low income
# 2      356.445240           Low income
# 3      350.550800           Low income
# 4      345.193250           Low income
# ...           ...                  ...
# 13975   61.654434  Lower middle income
# 13976   62.374770  Lower middle income
# 13977   64.036283  Lower middle income
# 13978   64.197530  Lower middle income
# 13979   64.660907  Lower middle income
#
# [13255 rows x 6 columns]

# %%
#Now region column from the so called income group data
mortality_under_5_new_2["regions"] = mortality_under_5_new_2[mortality_under_5_new_2['code'].isin(income_level['Code'])]['code'].map(income_level.set_index('Code')['region'])
mortality_under_5_new_2
# Out:
# /tmp/ipykernel_2533/2875599543.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mortality_under_5_new_2["regions"] = mortality_under_5_new_2[mortality_under_5_new_2['code'].isin(income_level['Code'])]['code'].map(income_level.set_index('Code')['region'])
#             entity code  year  \
# 0      Afghanistan  AFG  1957
# 1      Afghanistan  AFG  1958
# 2      Afghanistan  AFG  1959
# 3      Afghanistan  AFG  1960
# 4      Afghanistan  AFG  1961
# ...            ...  ...   ...
# 13975     Zimbabwe  ZWE  2020
# 13976     Zimbabwe  ZWE  2021
# 13977     Zimbabwe  ZWE  2022
# 13978     Zimbabwe  ZWE  2023
# 13979     Zimbabwe  ZWE  2024
#
#        observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births  \
# 0                                              36.819660
# 1                                              36.206852
# 2                                              35.644524
# 3                                              35.055080
# 4                                              34.519325
# ...                                                  ...
# 13975                                           6.165443
# 13976                                           6.237477
# 13977                                           6.403628
# 13978                                           6.419753
# 13979                                           6.466091
#
#          per_1000         income_level  \
# 0      368.196600           Low income
# 1      362.068520           Low income
# 2      356.445240           Low income
# 3      350.550800           Low income
# 4      345.193250           Low income
# ...           ...                  ...
# 13975   61.654434  Lower middle income
# 13976   62.374770  Lower middle income
# 13977   64.036283  Lower middle income
# 13978   64.197530  Lower middle income
# 13979   64.660907  Lower middle income
#
#                                                  regions
# 0      Middle East, North Africa, Afghanistan & Pakistan
# 1      Middle East, North Africa, Afghanistan & Pakistan
# 2      Middle East, North Africa, Afghanistan & Pakistan
# 3      Middle East, North Africa, Afghanistan & Pakistan
# 4      Middle East, North Africa, Afghanistan & Pakistan
# ...                                                  ...
# 13975                                Sub-Saharan Africa
# 13976                                Sub-Saharan Africa
# 13977                                Sub-Saharan Africa
# 13978                                Sub-Saharan Africa
# 13979                                Sub-Saharan Africa
#
# [13255 rows x 7 columns]

# %%
print(mortality_under_5_new_2.shape)
print(mortality_under_5_new_2.columns)
print(mortality_under_5_new_2.info())
print(mortality_under_5_new_2.isna().sum())
# Out:
# (13255, 7)
# Index(['entity', 'code', 'year',
#        'observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births',
#        'per_1000', 'income_level', 'regions'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 13255 entries, 0 to 13979
# Data columns (total 7 columns):
#  #   Column                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                           --------------  -----
#  0   entity                                                                                                                           13255 non-null  object
#  1   code                                                                                                                             13255 non-null  object
#  2   year                                                                                                                             13255 non-null  int64
#  3   observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births  13255 non-null  float64
#  4   per_1000                                                                                                                         13255 non-null  float64
#  5   income_level                                                                                                                     12992 non-null  object
#  6   regions                                                                                                                          12992 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 828.4+ KB
# None
# entity                                                                                                                               0
# code                                                                                                                                 0
# year                                                                                                                                 0
# observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births      0
# per_1000                                                                                                                             0
# income_level                                                                                                                       263
# regions                                                                                                                            263
# dtype: int64

# %%
#I waant to drop missing value in the data
mort_und_5_new_2_dropna = mortality_under_5_new_2.dropna()
print(mort_und_5_new_2_dropna.shape)
print(mort_und_5_new_2_dropna.isna().sum())
# Out:
# (12992, 7)
# entity                                                                                                                             0
# code                                                                                                                               0
# year                                                                                                                               0
# observation_value__indicator_child_mortality_rate__sex_total__wealth_quintile_total__unit_of_measure_deaths_per_100_live_births    0
# per_1000                                                                                                                           0
# income_level                                                                                                                       0
# regions                                                                                                                            0
# dtype: int64

# %%
#Since my interest is working on years from year 2000 to later year.
mort_und_5_new_2_dropna_2000 = mort_und_5_new_2_dropna[mort_und_5_new_2_dropna["year"] >= 2000]
print(mort_und_5_new_2_dropna_2000.shape)
# Out:
# (4875, 7)

# %%
print(mort_und_5_new_2_dropna["year"].unique())
print(mort_und_5_new_2_dropna_2000["year"].unique())
# Out:
# [1957 1958 1959 1960 1961 1962 1963 1964 1965 1966 1967 1968 1969 1970
#  1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
#  1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 1954 1955
#  1956 1949 1950 1951 1952 1953 1945 1946 1947 1948 1931 1932 1933 1934
#  1935 1936 1937 1938 1939 1940 1941 1942 1943 1944]
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024]

# %%
#validating which counties have dropped since i applied dropping missing valuea nd also
#applied filtered for years above 2000
print(mort_und_5_new_2_dropna_2000["code"].unique())
unique_coutries_2 = mort_und_5_new_2_dropna_2000["code"].unique()
print(len(unique_coutries_2))
# Out:
# ['AFG' 'ALB' 'DZA' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'AUS' 'AUT' 'AZE' 'BHS'
#  'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BTN' 'BOL' 'BIH' 'BWA' 'BRA'
#  'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'KHM' 'CMR' 'CAN' 'CPV' 'CAF' 'TCD' 'CHL'
#  'CHN' 'COL' 'COM' 'COG' 'CRI' 'CIV' 'HRV' 'CUB' 'CYP' 'CZE' 'COD' 'DNK'
#  'DJI' 'DMA' 'DOM' 'TLS' 'ECU' 'EGY' 'SLV' 'GNQ' 'ERI' 'EST' 'SWZ' 'ETH'
#  'FJI' 'FIN' 'FRA' 'GAB' 'GMB' 'GEO' 'DEU' 'GHA' 'GRC' 'GRD' 'GTM' 'GIN'
#  'GNB' 'GUY' 'HTI' 'HND' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'KWT' 'KGZ' 'LAO' 'LVA' 'LBN'
#  'LSO' 'LBR' 'LBY' 'LTU' 'LUX' 'MDG' 'MWI' 'MYS' 'MDV' 'MLI' 'MLT' 'MHL'
#  'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG' 'MNE' 'MAR' 'MOZ' 'MMR' 'NAM'
#  'NRU' 'NPL' 'NLD' 'NZL' 'NIC' 'NER' 'NGA' 'PRK' 'MKD' 'NOR' 'OMN' 'PAK'
#  'PLW' 'PSE' 'PAN' 'PNG' 'PRY' 'PER' 'PHL' 'POL' 'PRT' 'QAT' 'ROU' 'RUS'
#  'RWA' 'KNA' 'LCA' 'VCT' 'WSM' 'SMR' 'STP' 'SAU' 'SEN' 'SRB' 'SYC' 'SLE'
#  'SGP' 'SVK' 'SVN' 'SLB' 'SOM' 'ZAF' 'KOR' 'SSD' 'ESP' 'LKA' 'SDN' 'SUR'
#  'SWE' 'CHE' 'SYR' 'TJK' 'TZA' 'THA' 'TGO' 'TON' 'TTO' 'TUN' 'TUR' 'TKM'
#  'TCA' 'TUV' 'UGA' 'UKR' 'ARE' 'GBR' 'USA' 'URY' 'UZB' 'VUT' 'VEN' 'VNM'
#  'YEM' 'ZMB' 'ZWE']
# 195
